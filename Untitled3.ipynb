# %%
import tensorflow

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# !pip install -q tensorflow-datasets
import tensorflow_datasets as tfds

# %%
imdb,info = tfds.load("imdb_reviews",with_info=True,as_supervised=True)
# Out:
# Downloading and preparing dataset imdb_reviews/plain_text/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteRQZCUZ/imdb_reviews-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=25000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteRQZCUZ/imdb_reviews-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=25000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteRQZCUZ/imdb_reviews-unsupervised.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=50000.0), HTML(value='')))
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
import numpy as np
train_data,test_data = imdb['train'],imdb['test']

# %%
training_sentences = []
training_labels =[]
testing_sentences = []
testing_labels = []

# %%
for s,l in train_data:
  training_sentences.append(s.numpy().decode('utf-8'))
  training_labels.append(l.numpy())

# %%
for s,l in test_data:
  testing_sentences.append(s.numpy().decode('utf-8'))
  testing_labels.append(l.numpy())

# %%
testing_labels_final = np.array(testing_labels)
training_labels_final = np.array(training_labels)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer(num_words = 10000,oov_token ="<OOV>")
tokenizer.fit_on_texts(training_sentences)

# %%
word_index = tokenizer.word_index

# %%
sequences =  tokenizer.texts_to_sequences(training_sentences)

# %%
padded = pad_sequences(sequences,maxlen=120, truncating='post')

# %%
testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
paddedse = pad_sequences(testing_sequences,maxlen= 120)
word_index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dd0655ec4005> in <module>()
# ----> 1 testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
#       2 paddedse = pad_sequences(testing_sequences,maxlen= 120)
#       3 word_index
#
# NameError: name 'tokenizer' is not defined

# %%
reverse_word_index = dict([(value,key) for (key,value) in word_index.items()])
reversse_word_index
# Out:
# {1: '<OOV>',
#  2: 'the',
#  3: 'and',
#  4: 'a',
#  5: 'of',
#  6: 'to',
#  7: 'is',
#  8: 'br',
#  9: 'in',
#  10: 'it',
#  11: 'i',
#  12: 'this',
#  13: 'that',
#  14: 'was',
#  15: 'as',
#  16: 'for',
#  17: 'with',
#  18: 'movie',
#  19: 'but',
#  20: 'film',
#  21: 'on',
#  22: 'you',
#  23: 'not',
#  24: 'are',
#  25: 'his',
#  26: 'he',
#  27: 'have',
#  28: 'be',
#  29: 'one',
#  30: 'all',
#  31: 'at',
#  32: 'by',
#  33: 'they',
#  34: 'an',
#  35: 'who',
#  36: 'so',
#  37: 'from',
#  38: 'like',
#  39: "'s",
#  40: 'her',
#  41: 'or',
#  42: 'just',
#  43: 'about',
#  44: 'out',
#  45: 'has',
#  46: 'if',
#  47: 'there',
#  48: 'some',
#  49: 'what',
#  50: 'good',
#  51: 'more',
#  52: 'when',
#  53: 'very',
#  54: 'up',
#  55: 'she',
#  56: 'time',
#  57: 'no',
#  58: 'even',
#  59: 'my',
#  60: "it's",
#  61: 'would',
#  62: 'can',
#  63: 'which',
#  64: 'story',
#  65: 'only',
#  66: 'really',
#  67: 'see',
#  68: 'their',
#  69: 'had',
#  70: 'were',
#  71: 'me',
#  72: 'well',
#  73: 'we',
#  74: 'than',
#  75: 'much',
#  76: 'been',
#  77: 'get',
#  78: 'bad',
#  79: 'will',
#  80: 'do',
#  81: 'also',
#  82: 'people',
#  83: "'t",
#  84: 'into',
#  85: 'other',
#  86: 'because',
#  87: 'great',
#  88: 'first',
#  89: "'",
#  90: 'him',
#  91: 'how',
#  92: 'most',
#  93: 'made',
#  94: 'its',
#  95: 'then',
#  96: 'way',
#  97: 'make',
#  98: 'them',
#  99: 'too',
#  100: 'could',
#  101: 'any',
#  102: 'movies',
#  103: 'after',
#  104: 'think',
#  105: 'characters',
#  106: 'b',
#  107: 'watch',
#  108: 'two',
#  109: 'films',
#  110: 'character',
#  111: 'seen',
#  112: 'many',
#  113: 'being',
#  114: 'life',
#  115: 'plot',
#  116: 'acting',
#  117: 'never',
#  118: 'little',
#  119: 'best',
#  120: 'love',
#  121: 'where',
#  122: 'over',
#  123: 'did',
#  124: 'show',
#  125: "don't",
#  126: 'know',
#  127: 'off',
#  128: 'ever',
#  129: 'does',
#  130: 'better',
#  131: 'your',
#  132: 'man',
#  133: 'end',
#  134: 'still',
#  135: 'here',
#  136: 'these',
#  137: 'say',
#  138: 'scene',
#  139: 'while',
#  140: 'why',
#  141: 'scenes',
#  142: 'go',
#  143: 'such',
#  144: 'something',
#  145: 'should',
#  146: 'through',
#  147: 'back',
#  148: 'real',
#  149: 'those',
#  150: 'watching',
#  151: 'now',
#  152: 'though',
#  153: 'thing',
#  154: 'years',
#  155: 'old',
#  156: 'actors',
#  157: 'work',
#  158: 'another',
#  159: 'before',
#  160: 'new',
#  161: 'funny',
#  162: 'nothing',
#  163: 'director',
#  164: 'actually',
#  165: 'makes',
#  166: 'look',
#  167: 'find',
#  168: '10',
#  169: 'going',
#  170: 'few',
#  171: 'same',
#  172: 'part',
#  173: 'again',
#  174: 'lot',
#  175: 'every',
#  176: 'cast',
#  177: 'us',
#  178: 'quite',
#  179: 'world',
#  180: 'down',
#  181: 'want',
#  182: 'things',
#  183: 'pretty',
#  184: 'young',
#  185: 'seems',
#  186: 'around',
#  187: 'got',
#  188: 'horror',
#  189: 'however',
#  190: 'fact',
#  191: 'take',
#  192: 'big',
#  193: 'enough',
#  194: 'long',
#  195: 'thought',
#  196: "i'm",
#  197: 'both',
#  198: 'series',
#  199: 'between',
#  200: 'give',
#  201: 'may',
#  202: 'original',
#  203: 'own',
#  204: 'action',
#  205: 'right',
#  206: 'without',
#  207: "doesn't",
#  208: 'always',
#  209: 'times',
#  210: 'comedy',
#  211: 'point',
#  212: 'must',
#  213: 'gets',
#  214: 'come',
#  215: 'role',
#  216: "didn't",
#  217: 'saw',
#  218: 'almost',
#  219: 'family',
#  220: 'interesting',
#  221: 'least',
#  222: 'done',
#  223: 'whole',
#  224: 'bit',
#  225: 'music',
#  226: 'script',
#  227: 'far',
#  228: 'guy',
#  229: 'making',
#  230: 'anything',
#  231: 'minutes',
#  232: 'feel',
#  233: 'last',
#  234: 'might',
#  235: 'performance',
#  236: 'since',
#  237: '2',
#  238: 'probably',
#  239: 'kind',
#  240: 'am',
#  241: 'away',
#  242: 'girl',
#  243: 'tv',
#  244: 'yet',
#  245: 'rather',
#  246: 'worst',
#  247: 'day',
#  248: 'woman',
#  249: 'fun',
#  250: 'sure',
#  251: 'hard',
#  252: 'don',
#  253: 'played',
#  254: 'anyone',
#  255: 'each',
#  256: 'found',
#  257: 'especially',
#  258: "can't",
#  259: 'having',
#  260: 'our',
#  261: 'course',
#  262: 'although',
#  263: 'believe',
#  264: 'comes',
#  265: "i've",
#  266: 'looking',
#  267: 'screen',
#  268: 'trying',
#  269: 'set',
#  270: 'goes',
#  271: 'looks',
#  272: "that's",
#  273: 'place',
#  274: 'book',
#  275: 'different',
#  276: 'put',
#  277: 'ending',
#  278: 'money',
#  279: 'maybe',
#  280: 'actor',
#  281: 'sense',
#  282: 'reason',
#  283: 'true',
#  284: 'once',
#  285: 'everything',
#  286: 'shows',
#  287: 'year',
#  288: 'dvd',
#  289: "isn't",
#  290: 'three',
#  291: 'worth',
#  292: 'job',
#  293: 'someone',
#  294: 'main',
#  295: 'together',
#  296: 'watched',
#  297: 'play',
#  298: 'american',
#  299: 'plays',
#  300: '1',
#  301: 'said',
#  302: 'effects',
#  303: 'later',
#  304: 'takes',
#  305: "there's",
#  306: 'instead',
#  307: 'seem',
#  308: 'john',
#  309: 'beautiful',
#  310: 'himself',
#  311: 'audience',
#  312: 'version',
#  313: 'high',
#  314: 'everyone',
#  315: 'house',
#  316: 'night',
#  317: 'during',
#  318: 'left',
#  319: 'special',
#  320: 'seeing',
#  321: 'half',
#  322: 'wife',
#  323: 'excellent',
#  324: 'star',
#  325: 'shot',
#  326: 'war',
#  327: 'idea',
#  328: "he's",
#  329: 'nice',
#  330: 'black',
#  331: 'less',
#  332: 'father',
#  333: 'mind',
#  334: 'simply',
#  335: 'read',
#  336: 'second',
#  337: 'else',
#  338: 'fan',
#  339: 'help',
#  340: 'poor',
#  341: 'death',
#  342: 'completely',
#  343: '3',
#  344: 'used',
#  345: 'let',
#  346: 'home',
#  347: 'either',
#  348: 'short',
#  349: 'men',
#  350: 'line',
#  351: 'given',
#  352: 'dead',
#  353: 'top',
#  354: 'budget',
#  355: 'hollywood',
#  356: 'try',
#  357: 'performances',
#  358: 'wrong',
#  359: 'kids',
#  360: 'classic',
#  361: 'enjoy',
#  362: 'boring',
#  363: 'need',
#  364: 'rest',
#  365: 'use',
#  366: 'low',
#  367: 'production',
#  368: 'until',
#  369: 'friends',
#  370: 'along',
#  371: 'camera',
#  372: 'full',
#  373: 'women',
#  374: 'truly',
#  375: 'awful',
#  376: 'video',
#  377: "wasn't",
#  378: 'next',
#  379: 'tell',
#  380: 'couple',
#  381: 'remember',
#  382: 'stupid',
#  383: 'start',
#  384: 'mean',
#  385: 'sex',
#  386: 'stars',
#  387: 'perhaps',
#  388: 'came',
#  389: 'recommend',
#  390: 'moments',
#  391: 'wonderful',
#  392: 'episode',
#  393: 'understand',
#  394: 'small',
#  395: 'face',
#  396: 'school',
#  397: 'terrible',
#  398: 'playing',
#  399: 'getting',
#  400: 'written',
#  401: 'doing',
#  402: 'often',
#  403: 'early',
#  404: 'keep',
#  405: 'name',
#  406: 'perfect',
#  407: 'style',
#  408: 'human',
#  409: 'others',
#  410: 'definitely',
#  411: 'gives',
#  412: 'itself',
#  413: 'person',
#  414: 'lines',
#  415: 'live',
#  416: 'become',
#  417: 'dialogue',
#  418: 'lost',
#  419: 'piece',
#  420: 'head',
#  421: 'finally',
#  422: 'case',
#  423: 'felt',
#  424: 'supposed',
#  425: 'liked',
#  426: 'yes',
#  427: 'boy',
#  428: 'title',
#  429: 'xc2',
#  430: 'absolutely',
#  431: 'white',
#  432: 'against',
#  433: 'picture',
#  434: 'sort',
#  435: 'cinema',
#  436: 'worse',
#  437: 'certainly',
#  438: 'entire',
#  439: 'went',
#  440: 'waste',
#  441: 'problem',
#  442: 'hope',
#  443: 'mother',
#  444: 'entertaining',
#  445: 'mr',
#  446: 'overall',
#  447: 'evil',
#  448: 'called',
#  449: 'loved',
#  450: 'based',
#  451: 'several',
#  452: 'fans',
#  453: 'killer',
#  454: 'drama',
#  455: 'beginning',
#  456: 'oh',
#  457: 'friend',
#  458: 'lives',
#  459: '5',
#  460: 'direction',
#  461: 'care',
#  462: 'becomes',
#  463: 'children',
#  464: 'already',
#  465: 'laugh',
#  466: 'example',
#  467: "you're",
#  468: 'dark',
#  469: 'under',
#  470: 'seemed',
#  471: "'ve",
#  472: 'throughout',
#  473: '4',
#  474: 'turn',
#  475: 'wanted',
#  476: 'despite',
#  477: 'unfortunately',
#  478: 'history',
#  479: "'m",
#  480: 'fine',
#  481: 'final',
#  482: 'sound',
#  483: 'amazing',
#  484: 'heart',
#  485: 'son',
#  486: 'guess',
#  487: 'totally',
#  488: 'lead',
#  489: 'humor',
#  490: 'michael',
#  491: 'doesn',
#  492: 'writing',
#  493: 'quality',
#  494: 'close',
#  495: 'guys',
#  496: "b'i",
#  497: 'wants',
#  498: 'works',
#  499: 'behind',
#  500: 'tries',
#  501: 'side',
#  502: 'art',
#  503: 'xc3',
#  504: 'child',
#  505: 'game',
#  506: 'past',
#  507: 'days',
#  508: 'able',
#  509: 'turns',
#  510: 'hand',
#  511: 'town',
#  512: 'flick',
#  513: 'genre',
#  514: 'enjoyed',
#  515: 'act',
#  516: 'favorite',
#  517: 'kill',
#  518: 'soon',
#  519: 'starts',
#  520: 'car',
#  521: 'gave',
#  522: 'sometimes',
#  523: 'viewer',
#  524: 'run',
#  525: 'etc',
#  526: 'actress',
#  527: 'late',
#  528: 'eyes',
#  529: 'directed',
#  530: 'horrible',
#  531: 'brilliant',
#  532: 'parts',
#  533: 'themselves',
#  534: 'self',
#  535: 'hour',
#  536: 'girls',
#  537: 'expect',
#  538: 'thinking',
#  539: 'stories',
#  540: 'stuff',
#  541: 'city',
#  542: 'obviously',
#  543: 'blood',
#  544: 'decent',
#  545: 'didn',
#  546: 'voice',
#  547: 'highly',
#  548: 'myself',
#  549: 'feeling',
#  550: 'fight',
#  551: 'kid',
#  552: 'god',
#  553: "'re",
#  554: 'except',
#  555: 'matter',
#  556: 'slow',
#  557: 'type',
#  558: 'anyway',
#  559: 'roles',
#  560: 'writer',
#  561: 'killed',
#  562: 'heard',
#  563: 'age',
#  564: 'says',
#  565: 'moment',
#  566: 'took',
#  567: 'leave',
#  568: 'strong',
#  569: 'cannot',
#  570: 'violence',
#  571: "couldn't",
#  572: 'police',
#  573: 'daughter',
#  574: 'hit',
#  575: 'stop',
#  576: 'happens',
#  577: 'particularly',
#  578: 'known',
#  579: 'happened',
#  580: 'involved',
#  581: 's',
#  582: 'extremely',
#  583: 'obvious',
#  584: 'chance',
#  585: 'told',
#  586: 'living',
#  587: 'experience',
#  588: 'lack',
#  589: 'coming',
#  590: 'alone',
#  591: 'brother',
#  592: 'including',
#  593: 'today',
#  594: 'murder',
#  595: 'james',
#  596: 'attempt',
#  597: 'please',
#  598: 'happen',
#  599: 'wonder',
#  600: 'crap',
#  601: 'gore',
#  602: 'ago',
#  603: 'complete',
#  604: 'none',
#  605: 'interest',
#  606: 'group',
#  607: 'score',
#  608: 'cut',
#  609: 'simple',
#  610: 'save',
#  611: 'hell',
#  612: 'looked',
#  613: 'number',
#  614: 'career',
#  615: 'song',
#  616: "she's",
#  617: 'hero',
#  618: 'possible',
#  619: 'seriously',
#  620: 'annoying',
#  621: 'shown',
#  622: 'sad',
#  623: 'exactly',
#  624: 'running',
#  625: 'musical',
#  626: 'serious',
#  627: 'yourself',
#  628: 'taken',
#  629: 'whose',
#  630: 'david',
#  631: 'cinematography',
#  632: 'released',
#  633: 'scary',
#  634: 'ends',
#  635: 'english',
#  636: 'hours',
#  637: 'ok',
#  638: 'usually',
#  639: 'reality',
#  640: 'husband',
#  641: 'opening',
#  642: 'light',
#  643: 'jokes',
#  644: 'across',
#  645: 'hilarious',
#  646: 'somewhat',
#  647: 'body',
#  648: 'usual',
#  649: "i'd",
#  650: 'started',
#  651: 'cool',
#  652: 'relationship',
#  653: 'view',
#  654: 'level',
#  655: 'ridiculous',
#  656: 'change',
#  657: 'opinion',
#  658: 'happy',
#  659: 'middle',
#  660: 'wish',
#  661: 'taking',
#  662: "you'll",
#  663: 'ones',
#  664: 'finds',
#  665: 'talking',
#  666: 'novel',
#  667: 'order',
#  668: 'saying',
#  669: 'shots',
#  670: 'documentary',
#  671: 'huge',
#  672: 'female',
#  673: 'mostly',
#  674: 'power',
#  675: 'room',
#  676: 'robert',
#  677: 'episodes',
#  678: 'important',
#  679: 'talent',
#  680: 'rating',
#  681: 'five',
#  682: 'major',
#  683: 'turned',
#  684: 'strange',
#  685: 'word',
#  686: 'modern',
#  687: 'king',
#  688: 'call',
#  689: 'single',
#  690: 'disappointed',
#  691: 'apparently',
#  692: "b'this",
#  693: 'events',
#  694: 'due',
#  695: 'songs',
#  696: 'attention',
#  697: 'four',
#  698: '7',
#  699: 'country',
#  700: 'basically',
#  701: 'knows',
#  702: 'earth',
#  703: 'television',
#  704: 'clearly',
#  705: 'supporting',
#  706: 'comic',
#  707: 'knew',
#  708: 'non',
#  709: 'british',
#  710: 'isn',
#  711: 'fast',
#  712: 'future',
#  713: 'jack',
#  714: 'class',
#  715: '8',
#  716: 'cheap',
#  717: 'thriller',
#  718: 'silly',
#  719: 'problems',
#  720: 'easily',
#  721: 'tells',
#  722: 'miss',
#  723: 'words',
#  724: 'local',
#  725: 'sequence',
#  726: 'paul',
#  727: 'entertainment',
#  728: 'bring',
#  729: 'beyond',
#  730: "they're",
#  731: 'upon',
#  732: "won't",
#  733: 'whether',
#  734: 'straight',
#  735: 'moving',
#  736: 'sets',
#  737: 'predictable',
#  738: 'similar',
#  739: 'oscar',
#  740: 'romantic',
#  741: 'rock',
#  742: 'review',
#  743: 'falls',
#  744: 'mystery',
#  745: 'enjoyable',
#  746: 'george',
#  747: 'needs',
#  748: 'appears',
#  749: 'talk',
#  750: 'giving',
#  751: 'eye',
#  752: 'within',
#  753: 'richard',
#  754: 'ten',
#  755: 'animation',
#  756: 'message',
#  757: 'theater',
#  758: 'won',
#  759: 'near',
#  760: 'lady',
#  761: 'above',
#  762: 'nearly',
#  763: 'sequel',
#  764: 'theme',
#  765: 'dull',
#  766: 'points',
#  767: 'stand',
#  768: 'mention',
#  769: 'bunch',
#  770: 'team',
#  771: 'add',
#  772: 'herself',
#  773: 'feels',
#  774: 'release',
#  775: 'storyline',
#  776: "'ll",
#  777: 'red',
#  778: 'surprised',
#  779: 'ways',
#  780: 'named',
#  781: 'using',
#  782: 'lots',
#  783: 'easy',
#  784: 'fantastic',
#  785: 'begins',
#  786: 'york',
#  787: 'actual',
#  788: 'working',
#  789: 'effort',
#  790: 'sister',
#  791: 'tale',
#  792: 'die',
#  793: 'hate',
#  794: 'minute',
#  795: 'french',
#  796: 'clear',
#  797: 'stay',
#  798: 'feature',
#  799: 'elements',
#  800: '9',
#  801: 'among',
#  802: 'follow',
#  803: 'viewers',
#  804: 're',
#  805: 'comments',
#  806: 'avoid',
#  807: 'showing',
#  808: 'editing',
#  809: 'typical',
#  810: 'tried',
#  811: 't',
#  812: 'famous',
#  813: 'fall',
#  814: 'dialog',
#  815: 'check',
#  816: 'period',
#  817: 'season',
#  818: 'sorry',
#  819: 'form',
#  820: 'certain',
#  821: 'filmed',
#  822: 'soundtrack',
#  823: "wouldn't",
#  824: 'means',
#  825: 'weak',
#  826: 'buy',
#  827: 'tom',
#  828: 'material',
#  829: 'lee',
#  830: 'realistic',
#  831: 'figure',
#  832: 'crime',
#  833: 'somehow',
#  834: 'doubt',
#  835: 'peter',
#  836: 'gone',
#  837: 'general',
#  838: 'kept',
#  839: 'viewing',
#  840: 'leads',
#  841: 'greatest',
#  842: 'space',
#  843: 'lame',
#  844: 'suspense',
#  845: 'dance',
#  846: 'parents',
#  847: 'third',
#  848: 'brought',
#  849: 'atmosphere',
#  850: 'imagine',
#  851: 'hear',
#  852: 'particular',
#  853: 'sequences',
#  854: 'whatever',
#  855: 'move',
#  856: 'indeed',
#  857: 'rent',
#  858: 'eventually',
#  859: 'learn',
#  860: 'de',
#  861: 'deal',
#  862: 'reviews',
#  863: 'wait',
#  864: 'note',
#  865: 'average',
#  866: 'japanese',
#  867: 'forget',
#  868: 'sexual',
#  869: 'zombie',
#  870: 'poorly',
#  871: 'premise',
#  872: 'surprise',
#  873: 'believable',
#  874: 'stage',
#  875: 'sit',
#  876: "film's",
#  877: 'possibly',
#  878: 'decided',
#  879: 'expected',
#  880: 'subject',
#  881: 'nature',
#  882: 'became',
#  883: 'free',
#  884: 'difficult',
#  885: 'screenplay',
#  886: "i'll",
#  887: 'killing',
#  888: 'truth',
#  889: "'d",
#  890: 'romance',
#  891: 'okay',
#  892: 'dr',
#  893: 'nor',
#  894: 'disney',
#  895: '20',
#  896: 'question',
#  897: 'needed',
#  898: 'street',
#  899: 'reading',
#  900: 'leaves',
#  901: 'imdb',
#  902: 'meets',
#  903: 'hot',
#  904: 'baby',
#  905: 'begin',
#  906: 'unless',
#  907: 'credits',
#  908: 'otherwise',
#  909: 'superb',
#  910: 'write',
#  911: 'america',
#  912: 'x96',
#  913: 'dog',
#  914: '\x96',
#  915: 'directors',
#  916: 'shame',
#  917: 'joe',
#  918: 'situation',
#  919: 'dramatic',
#  920: 'memorable',
#  921: 'earlier',
#  922: 'open',
#  923: 'badly',
#  924: 'weird',
#  925: 'meet',
#  926: 'male',
#  927: 'society',
#  928: 'acted',
#  929: 'forced',
#  930: 'emotional',
#  931: 'sci',
#  932: 'laughs',
#  933: 'fi',
#  934: 'older',
#  935: 'dream',
#  936: 'realize',
#  937: 'writers',
#  938: 'interested',
#  939: 'forward',
#  940: 'footage',
#  941: 'comment',
#  942: 'crazy',
#  943: 'deep',
#  944: 'beauty',
#  945: 'whom',
#  946: 'fantasy',
#  947: 'sounds',
#  948: 'plus',
#  949: 'directing',
#  950: 'keeps',
#  951: 'ask',
#  952: 'development',
#  953: 'features',
#  954: 'air',
#  955: 'quickly',
#  956: 'mess',
#  957: 'creepy',
#  958: 'perfectly',
#  959: 'towards',
#  960: 'mark',
#  961: 'box',
#  962: 'worked',
#  963: 'monster',
#  964: "aren't",
#  965: 'setting',
#  966: 'cheesy',
#  967: 'unique',
#  968: 'result',
#  969: 'hands',
#  970: 'plenty',
#  971: 'brings',
#  972: 'e',
#  973: 'previous',
#  974: 'effect',
#  975: 'total',
#  976: 'personal',
#  977: 'incredibly',
#  978: 'fire',
#  979: 'rate',
#  980: 'business',
#  981: 'leading',
#  982: 'casting',
#  983: 'admit',
#  984: 'joke',
#  985: 'girlfriend',
#  986: 'apart',
#  987: 'appear',
#  988: 'background',
#  989: 'powerful',
#  990: 'bill',
#  991: 'telling',
#  992: 'meant',
#  993: 'present',
#  994: 'christmas',
#  995: 'potential',
#  996: 'battle',
#  997: 'hardly',
#  998: 'create',
#  999: 'break',
#  1000: 'jane',
#  ...}

# %%
def decode_review(text):
  return ' '.join([reverse_word_index.get(i,'?') for i in text])
print(decode_review(padded[4]))
print(training_sentences[4])
# Out:
# ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? b'as others have mentioned all the women that go nude in this film are mostly absolutely gorgeous the plot very <OOV> shows the <OOV> of the female <OOV> when men are around they want to be pursued but when no men are around they become the <OOV> of a 14 year old boy and the boy becomes a man really fast we should all be so lucky at this age he then gets up the courage to pursue his true love '
# b'As others have mentioned, all the women that go nude in this film are mostly absolutely gorgeous. The plot very ably shows the hypocrisy of the female libido. When men are around they want to be pursued, but when no "men" are around, they become the pursuers of a 14 year old boy. And the boy becomes a man really fast (we should all be so lucky at this age!). He then gets up the courage to pursue his true love.'

# %%
import tensorflow as tf

vocab_size = 10000
embedding_dim = 16
model  = tf.keras.Sequential([
                              tf.keras.layers.Embedding(vocab_size,embedding_dim,input_length = 120),
                              tf.keras.layers.Flatten(),
                              tf.keras.layers.Dense(6,activation = "relu"),
                              tf.keras.layers.Dense(1,activation = 'sigmoid')
])
model.compile(loss ="binary_crossentropy",optimizer= "adam",metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1920)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 11526
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 171,533
# Trainable params: 171,533
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 10
model.fit(padded,training_labels_final,epochs= num_epochs,validation_data = (paddedse,testing_labels_final))
# Out:
# Epoch 1/10
# 2344/2344 [==============================] - 6s 3ms/step - loss: 0.2956 - accuracy: 0.8700 - val_loss: 0.4317 - val_accuracy: 0.8267
# Epoch 2/10
# 2344/2344 [==============================] - 6s 3ms/step - loss: 0.0398 - accuracy: 0.9896 - val_loss: 0.6776 - val_accuracy: 0.8176
# Epoch 3/10
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.8397 - val_accuracy: 0.8186
# Epoch 4/10
# 2344/2344 [==============================] - 6s 3ms/step - loss: 4.6439e-04 - accuracy: 1.0000 - val_loss: 0.9593 - val_accuracy: 0.8225
# Epoch 5/10
# 2344/2344 [==============================] - 6s 3ms/step - loss: 7.5624e-05 - accuracy: 1.0000 - val_loss: 1.0549 - val_accuracy: 0.8245
# Epoch 6/10
# 2344/2344 [==============================] - 7s 3ms/step - loss: 1.6539e-05 - accuracy: 1.0000 - val_loss: 1.1441 - val_accuracy: 0.8262
# Epoch 7/10
# 2344/2344 [==============================] - 7s 3ms/step - loss: 4.9133e-06 - accuracy: 1.0000 - val_loss: 1.2467 - val_accuracy: 0.8256
# Epoch 8/10
# 2344/2344 [==============================] - 7s 3ms/step - loss: 1.4165e-06 - accuracy: 1.0000 - val_loss: 1.3456 - val_accuracy: 0.8260
# Epoch 9/10
# 2344/2344 [==============================] - 7s 3ms/step - loss: 4.0605e-07 - accuracy: 1.0000 - val_loss: 1.4525 - val_accuracy: 0.8258
# Epoch 10/10
# 2344/2344 [==============================] - 7s 3ms/step - loss: 1.2437e-07 - accuracy: 1.0000 - val_loss: 1.5499 - val_accuracy: 0.8261

# %%
e = model.layers[0]
weights = e.get_weights()[0]
print(weights.shape)
# Out:
# (10000, 16)

# %%
import io 
out_v=io.open('vecs.tsv','w',encoding='utf-8')
out_m=io.open('meta.tsv','w',encoding='utf-8')
for word_num in range(1,vocab_size):
  word = reverse_word_index[word_num]
  embeddings = weights[word_num]
  out_m.write(word+"\n")
  out_v.write('\t'.join([str(x) for x in embeddings])+"\n")

# %%
out_v.close()
out_m.close()

# %%
try:
  from google.colab import files
except ImportError:
  pass
else:
  files.download('vecs.tsv')
  files.download('meta.tsv')
